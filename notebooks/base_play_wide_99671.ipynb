# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop, Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 970M (CNMeM is disabled, cuDNN not available)

# %%
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")

# %%
Y_train = train["label"]

# Drop 'label' column
X_train = train.drop(labels = ["label"],axis = 1) 

# free some space
del train

# %%
# Normalize the data
X_train = X_train / 255.0
test = test / 255.0
# Reshape image in 3 dimensions (height = 28px, width = 28px , canal = 1)
X_train = X_train.values.reshape(-1,1,28,28)
test = test.values.reshape(-1,1,28,28)

# %%
Y_train = to_categorical(Y_train, num_classes = 10)

# set random seed for network, maybe not useful
from numpy.random import seed 
seed(42)

# Split the train and the validation set for the fitting
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.1, random_state=2)
print(X_train.shape, Y_train.shape)
# Out:
# (37800, 1, 28, 28) (37800, 10)

# %%
model = Sequential()

# conv1
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu', input_shape = (1,28,28)))
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

# conv2
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu'))
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

# conv3
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu'))
model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))


# flatten
model.add(Flatten())
model.add(Dense(512, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(256, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(10, activation = "softmax"))
# Compile the model

opt = Adam(lr=0.001)
model.compile(optimizer = opt , loss = "categorical_crossentropy", metrics=["accuracy"])
print("compile done")
# Out:
# compile done

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(X_train)
# Out:
# /home/jac/.local/lib/python3.5/site-packages/keras/preprocessing/image.py:653: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_first" (channels on axis 1), i.e. expected either 1, 3 or 4 channels on axis 1. However, it was passed an array with shape (37800, 1, 28, 28) (1 channels).
#   ' (' + str(x.shape[self.channel_axis]) + ' channels).')

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.models import load_model

learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.6, 
                                            min_lr=0.00001)
    
best_model_path = 'wide_best_m_v2.h5'
best_model = ModelCheckpoint(filepath=best_model_path, monitor='val_loss', save_best_only=True, verbose=1)
epochs = 100
steps_per_epoch = 100
batch_size = 64
model.fit_generator(datagen.flow(X_train,Y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (X_val,Y_val),
                              verbose = 2, steps_per_epoch=steps_per_epoch,
                              callbacks=[best_model,learning_rate_reduction])
# Out:
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.18777, saving model to wide_best_m_v2.h5
# 15s - loss: 1.1244 - acc: 0.6019 - val_loss: 0.1878 - val_acc: 0.9421
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.18777 to 0.09670, saving model to wide_best_m_v2.h5
# 14s - loss: 0.2834 - acc: 0.9156 - val_loss: 0.0967 - val_acc: 0.9686
# Epoch 3/100
# Epoch 00002: val_loss improved from 0.09670 to 0.08998, saving model to wide_best_m_v2.h5
# 14s - loss: 0.1686 - acc: 0.9498 - val_loss: 0.0900 - val_acc: 0.9707
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 13s - loss: 0.0130 - acc: 0.9959 - val_loss: 0.0146 - val_acc: 0.9952
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 13s - loss: 0.0138 - acc: 0.9969 - val_loss: 0.0138 - val_acc: 0.9960
# Epoch 80/100
# Epoch 00079: val_loss improved from 0.01312 to 0.01309, saving model to wide_best_m_v2.h5
# 13s - loss: 0.0136 - acc: 0.9961 - val_loss: 0.0131 - val_acc: 0.9962
# Epoch 81/100
# Epoch 00080: val_loss did not improve
#
# Epoch 00080: reducing learning rate to 1.6796160707599483e-05.
# 13s - loss: 0.0167 - acc: 0.9955 - val_loss: 0.0141 - val_acc: 0.9960
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 14s - loss: 0.0159 - acc: 0.9942 - val_loss: 0.0140 - val_acc: 0.9960
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 13s - loss: 0.0134 - acc: 0.9958 - val_loss: 0.0143 - val_acc: 0.9957
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 13s - loss: 0.0134 - acc: 0.9956 - val_loss: 0.0142 - val_acc: 0.9957
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 13s - loss: 0.0141 - acc: 0.9959 - val_loss: 0.0151 - val_acc: 0.9957
# Epoch 86/100
# Epoch 00085: val_loss did not improve
#
# Epoch 00085: reducing learning rate to 1.007769642455969e-05.
# 14s - loss: 0.0198 - acc: 0.9952 - val_loss: 0.0151 - val_acc: 0.9960
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 13s - loss: 0.0151 - acc: 0.9953 - val_loss: 0.0149 - val_acc: 0.9957
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 13s - loss: 0.0119 - acc: 0.9967 - val_loss: 0.0152 - val_acc: 0.9957
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 13s - loss: 0.0090 - acc: 0.9977 - val_loss: 0.0153 - val_acc: 0.9955
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 13s - loss: 0.0127 - acc: 0.9958 - val_loss: 0.0149 - val_acc: 0.9957
# Epoch 91/100
# Epoch 00090: val_loss did not improve
#
# Epoch 00090: reducing learning rate to 1e-05.
# 13s - loss: 0.0144 - acc: 0.9953 - val_loss: 0.0151 - val_acc: 0.9955
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 13s - loss: 0.0133 - acc: 0.9955 - val_loss: 0.0154 - val_acc: 0.9952
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 13s - loss: 0.0189 - acc: 0.9939 - val_loss: 0.0152 - val_acc: 0.9955
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 13s - loss: 0.0147 - acc: 0.9952 - val_loss: 0.0150 - val_acc: 0.9957
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 13s - loss: 0.0130 - acc: 0.9952 - val_loss: 0.0149 - val_acc: 0.9960
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 13s - loss: 0.0101 - acc: 0.9973 - val_loss: 0.0148 - val_acc: 0.9957
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 13s - loss: 0.0103 - acc: 0.9966 - val_loss: 0.0152 - val_acc: 0.9960
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 13s - loss: 0.0130 - acc: 0.9955 - val_loss: 0.0155 - val_acc: 0.9960
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 13s - loss: 0.0138 - acc: 0.9956 - val_loss: 0.0156 - val_acc: 0.9957
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 13s - loss: 0.0110 - acc: 0.9970 - val_loss: 0.0156 - val_acc: 0.9957

# %%
model = load_model(best_model_path)  # try callback model
# predict results
results = model.predict(test)
# select the indix with the maximum probability
results = np.argmax(results,axis = 1)
results = pd.Series(results,name="Label")
import arrow
ts = str(arrow.now())[:-10].replace(':','_').replace('.',"_")
res_file = "wide_play_cnn_mnist_datagen_{}.csv".format(ts)
submission = pd.concat([pd.Series(range(1,28001),name = "ImageId"),results],axis = 1)
submission.to_csv(res_file,index=False)
print('save done',res_file)
# Out:
# save done wide_play_cnn_mnist_datagen_2017-09-07T11_30_46_70.csv
